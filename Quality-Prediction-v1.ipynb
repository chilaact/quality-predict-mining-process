# %% [markdown]
# <a href="https://colab.research.google.com/github/chilaact/quality-predict-mining-process/blob/iqbal-branch/Quality-Control-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use seaborn for pairplot
# !pip install -q seaborn

# Use some functions from tensorflow_docs
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
# Importing some useful modules

from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
#Importing TensorFlow 2.x

# %tensorflow_version 2.x
import tensorflow as tf

print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Load the Data
data = pd.read_csv("/content/drive/My Drive/Quality_Prediction/MiningProcess_Flotation_Plant_Database.csv",
                   decimal=",",parse_dates=["date"],infer_datetime_format=True).drop_duplicates()

# %%
data.head()
# Out:
#                  date  % Iron Feed  ...  % Iron Concentrate  % Silica Concentrate
# 0 2017-03-10 01:00:00         55.2  ...               66.91                  1.31
# 1 2017-03-10 01:00:00         55.2  ...               66.91                  1.31
# 2 2017-03-10 01:00:00         55.2  ...               66.91                  1.31
# 3 2017-03-10 01:00:00         55.2  ...               66.91                  1.31
# 4 2017-03-10 01:00:00         55.2  ...               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
data.isna().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
data.describe().transpose()
# Out:
#                                  count         mean  ...         75%         max
# % Iron Feed                   736282.0    56.298307  ...    59.72000    65.78000
# % Silica Feed                 736282.0    14.648984  ...    19.60000    33.40000
# Starch Flow                   736282.0  2869.636615  ...  3728.93000  6300.23000
# Amina Flow                    736282.0   488.165523  ...   553.33575   739.53800
# Ore Pulp Flow                 736282.0   397.570736  ...   402.96700   418.64100
# Ore Pulp pH                   736282.0     9.767315  ...    10.03780    10.80810
# Ore Pulp Density              736282.0     1.680424  ...     1.72838     1.85325
# Flotation Column 01 Air Flow  736282.0   280.119813  ...   300.14700   373.87100
# Flotation Column 02 Air Flow  736282.0   277.121249  ...   300.68600   375.99200
# Flotation Column 03 Air Flow  736282.0   281.052538  ...   300.38500   364.34600
# Flotation Column 04 Air Flow  736282.0   299.446217  ...   300.63500   305.87100
# Flotation Column 05 Air Flow  736282.0   299.914815  ...   301.78500   310.27000
# Flotation Column 06 Air Flow  736282.0   292.065742  ...   303.07700   370.91000
# Flotation Column 07 Air Flow  736282.0   290.740507  ...   301.90700   371.59300
# Flotation Column 01 Level     736282.0   520.168402  ...   594.09775   862.27400
# Flotation Column 02 Level     736282.0   522.555279  ...   595.29300   828.91900
# Flotation Column 03 Level     736282.0   531.283790  ...   601.29900   886.82200
# Flotation Column 04 Level     736282.0   420.169753  ...   485.28500   680.35900
# Flotation Column 05 Level     736282.0   425.094530  ...   484.00800   675.64400
# Flotation Column 06 Level     736282.0   429.889517  ...   492.77300   698.86100
# Flotation Column 07 Level     736282.0   420.910258  ...   476.14500   659.90200
# % Iron Concentrate            736282.0    65.049096  ...    65.86000    68.01000
# % Silica Concentrate          736282.0     2.327270  ...     3.01000     5.53000
#
# [23 rows x 8 columns]

# %%
#Do some pre-processing
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import MinMaxScaler as mms

no_date_data = data.drop('date', axis=1)

y = no_date_data['% Silica Concentrate']
X = no_date_data.drop('% Silica Concentrate', axis=1)

X_train, X_test, y_train, y_test = tts(X, y, random_state=100)

# %%
X_train.head()
# Out:
#         % Iron Feed  ...  % Iron Concentrate
# 122061        53.51  ...           64.580000
# 40590         59.72  ...           64.030000
# 629574        54.91  ...           65.740000
# 548738        57.46  ...           64.780000
# 720164        56.20  ...           63.664933
#
# [5 rows x 22 columns]

# %%
#Scaling the features

scaler = mms()

X_train=pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns,index=X_train.index)

X_test=pd.DataFrame(scaler.fit_transform(X_test),columns=X_test.columns,index=X_test.index)

# %%
X_train.head()
# Out:
#         % Iron Feed  ...  % Iron Concentrate
# 122061     0.467448  ...            0.424497
# 40590      0.736979  ...            0.332215
# 629574     0.528212  ...            0.619128
# 548738     0.638889  ...            0.458054
# 720164     0.584201  ...            0.270962
#
# [5 rows x 22 columns]

# %%
#building the model

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(64, activation=tf.nn.relu, input_shape=[len(X_train.columns)]),
                             tf.keras.layers.Dense(64, activation=tf.nn.relu),
                             tf.keras.layers.Dense(1)
])

model.compile(loss='mse',
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['mae', 'mse'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                1472
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,697
# Trainable params: 5,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
  X_train, y_train,
  epochs=100, validation_split = 0.2)
# Out:
# Train on 441768 samples, validate on 110443 samples
# Epoch 1/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1313 - mae: 0.2648 - mse: 0.1313 - val_loss: 0.1306 - val_mae: 0.2642 - val_mse: 0.1306
# Epoch 2/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1304 - mae: 0.2638 - mse: 0.1304 - val_loss: 0.1371 - val_mae: 0.2688 - val_mse: 0.1371
# Epoch 3/100
# 441768/441768 [==============================] - 44s 100us/sample - loss: 0.1296 - mae: 0.2630 - mse: 0.1296 - val_loss: 0.1352 - val_mae: 0.2680 - val_mse: 0.1352
# Epoch 4/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1287 - mae: 0.2623 - mse: 0.1287 - val_loss: 0.1334 - val_mae: 0.2632 - val_mse: 0.1334
# Epoch 5/100
# 441768/441768 [==============================] - 43s 98us/sample - loss: 0.1277 - mae: 0.2611 - mse: 0.1277 - val_loss: 0.1283 - val_mae: 0.2582 - val_mse: 0.1283
# Epoch 6/100
# 441768/441768 [==============================] - 44s 99us/sample - loss: 0.1270 - mae: 0.2604 - mse: 0.1270 - val_loss: 0.1290 - val_mae: 0.2599 - val_mse: 0.1290
# Epoch 7/100
# 441768/441768 [==============================] - 44s 99us/sample - loss: 0.1261 - mae: 0.2594 - mse: 0.1261 - val_loss: 0.1264 - val_mae: 0.2604 - val_mse: 0.1264
# Epoch 8/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1254 - mae: 0.2588 - mse: 0.1254 - val_loss: 0.1287 - val_mae: 0.2624 - val_mse: 0.1287
# Epoch 9/100
# 441768/441768 [==============================] - 44s 99us/sample - loss: 0.1249 - mae: 0.2584 - mse: 0.1249 - val_loss: 0.1310 - val_mae: 0.2628 - val_mse: 0.1310
# Epoch 10/100
# 441768/441768 [==============================] - 44s 99us/sample - loss: 0.1239 - mae: 0.2571 - mse: 0.1239 - val_loss: 0.1269 - val_mae: 0.2571 - val_mse: 0.1269
# Epoch 11/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1235 - mae: 0.2569 - mse: 0.1235 - val_loss: 0.1274 - val_mae: 0.2604 - val_mse: 0.1274
# Epoch 12/100
# 441768/441768 [==============================] - 44s 99us/sample - loss: 0.1232 - mae: 0.2565 - mse: 0.1232 - val_loss: 0.1275 - val_mae: 0.2565 - val_mse: 0.1275
# Epoch 13/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1224 - mae: 0.2556 - mse: 0.1224 - val_loss: 0.1232 - val_mae: 0.2552 - val_mse: 0.1232
# Epoch 14/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1217 - mae: 0.2550 - mse: 0.1217 - val_loss: 0.1244 - val_mae: 0.2564 - val_mse: 0.1244
# Epoch 15/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1210 - mae: 0.2542 - mse: 0.1210 - val_loss: 0.1251 - val_mae: 0.2559 - val_mse: 0.1251
# Epoch 16/100
# 441768/441768 [==============================] - 44s 100us/sample - loss: 0.1206 - mae: 0.2538 - mse: 0.1206 - val_loss: 0.1244 - val_mae: 0.2555 - val_mse: 0.1244
# Epoch 17/100
# 441768/441768 [==============================] - 44s 101us/sample - loss: 0.1202 - mae: 0.2534 - mse: 0.1202 - val_loss: 0.1215 - val_mae: 0.2541 - val_mse: 0.1215
# Epoch 18/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1195 - mae: 0.2528 - mse: 0.1195 - val_loss: 0.1236 - val_mae: 0.2599 - val_mse: 0.1236
# Epoch 19/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1189 - mae: 0.2521 - mse: 0.1189 - val_loss: 0.1207 - val_mae: 0.2516 - val_mse: 0.1207
# Epoch 20/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1185 - mae: 0.2516 - mse: 0.1185 - val_loss: 0.1248 - val_mae: 0.2579 - val_mse: 0.1248
# Epoch 21/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1182 - mae: 0.2516 - mse: 0.1182 - val_loss: 0.1215 - val_mae: 0.2539 - val_mse: 0.1215
# Epoch 22/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1177 - mae: 0.2511 - mse: 0.1177 - val_loss: 0.1224 - val_mae: 0.2557 - val_mse: 0.1224
# Epoch 23/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1174 - mae: 0.2508 - mse: 0.1174 - val_loss: 0.1212 - val_mae: 0.2550 - val_mse: 0.1212
# Epoch 24/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1170 - mae: 0.2501 - mse: 0.1170 - val_loss: 0.1205 - val_mae: 0.2530 - val_mse: 0.1205
# Epoch 25/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1166 - mae: 0.2499 - mse: 0.1166 - val_loss: 0.1222 - val_mae: 0.2520 - val_mse: 0.1222
# Epoch 26/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1160 - mae: 0.2491 - mse: 0.1160 - val_loss: 0.1176 - val_mae: 0.2503 - val_mse: 0.1176
# Epoch 27/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1156 - mae: 0.2488 - mse: 0.1156 - val_loss: 0.1243 - val_mae: 0.2551 - val_mse: 0.1243
# Epoch 28/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1154 - mae: 0.2486 - mse: 0.1154 - val_loss: 0.1196 - val_mae: 0.2553 - val_mse: 0.1196
# Epoch 29/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1149 - mae: 0.2481 - mse: 0.1149 - val_loss: 0.1220 - val_mae: 0.2548 - val_mse: 0.1220
# Epoch 30/100
# 441768/441768 [==============================] - 45s 101us/sample - loss: 0.1149 - mae: 0.2480 - mse: 0.1149 - val_loss: 0.1155 - val_mae: 0.2457 - val_mse: 0.1155
# Epoch 31/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1143 - mae: 0.2473 - mse: 0.1143 - val_loss: 0.1328 - val_mae: 0.2676 - val_mse: 0.1328
# Epoch 32/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1141 - mae: 0.2471 - mse: 0.1141 - val_loss: 0.1142 - val_mae: 0.2462 - val_mse: 0.1142
# Epoch 33/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1137 - mae: 0.2468 - mse: 0.1137 - val_loss: 0.1176 - val_mae: 0.2523 - val_mse: 0.1176
# Epoch 34/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1134 - mae: 0.2464 - mse: 0.1134 - val_loss: 0.1182 - val_mae: 0.2508 - val_mse: 0.1182
# Epoch 35/100
# 441768/441768 [==============================] - 46s 105us/sample - loss: 0.1131 - mae: 0.2463 - mse: 0.1131 - val_loss: 0.1258 - val_mae: 0.2599 - val_mse: 0.1258
# Epoch 36/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1128 - mae: 0.2459 - mse: 0.1128 - val_loss: 0.1159 - val_mae: 0.2475 - val_mse: 0.1159
# Epoch 37/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1125 - mae: 0.2454 - mse: 0.1125 - val_loss: 0.1139 - val_mae: 0.2442 - val_mse: 0.1139
# Epoch 38/100
# 441768/441768 [==============================] - 46s 105us/sample - loss: 0.1124 - mae: 0.2455 - mse: 0.1124 - val_loss: 0.1166 - val_mae: 0.2500 - val_mse: 0.1166
# Epoch 39/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1120 - mae: 0.2450 - mse: 0.1120 - val_loss: 0.1215 - val_mae: 0.2537 - val_mse: 0.1215
# Epoch 40/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1118 - mae: 0.2448 - mse: 0.1118 - val_loss: 0.1148 - val_mae: 0.2461 - val_mse: 0.1148
# Epoch 41/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1118 - mae: 0.2448 - mse: 0.1118 - val_loss: 0.1145 - val_mae: 0.2451 - val_mse: 0.1145
# Epoch 42/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1113 - mae: 0.2441 - mse: 0.1113 - val_loss: 0.1143 - val_mae: 0.2480 - val_mse: 0.1143
# Epoch 43/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1110 - mae: 0.2440 - mse: 0.1110 - val_loss: 0.1165 - val_mae: 0.2475 - val_mse: 0.1165
# Epoch 44/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1108 - mae: 0.2437 - mse: 0.1108 - val_loss: 0.1131 - val_mae: 0.2435 - val_mse: 0.1131
# Epoch 45/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1107 - mae: 0.2435 - mse: 0.1107 - val_loss: 0.1136 - val_mae: 0.2469 - val_mse: 0.1136
# Epoch 46/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1103 - mae: 0.2432 - mse: 0.1103 - val_loss: 0.1129 - val_mae: 0.2417 - val_mse: 0.1129
# Epoch 47/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1102 - mae: 0.2430 - mse: 0.1102 - val_loss: 0.1174 - val_mae: 0.2490 - val_mse: 0.1174
# Epoch 48/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1099 - mae: 0.2429 - mse: 0.1099 - val_loss: 0.1127 - val_mae: 0.2418 - val_mse: 0.1127
# Epoch 49/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1096 - mae: 0.2424 - mse: 0.1096 - val_loss: 0.1130 - val_mae: 0.2442 - val_mse: 0.1130
# Epoch 50/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1095 - mae: 0.2422 - mse: 0.1095 - val_loss: 0.1135 - val_mae: 0.2436 - val_mse: 0.1135
# Epoch 51/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1094 - mae: 0.2423 - mse: 0.1094 - val_loss: 0.1121 - val_mae: 0.2437 - val_mse: 0.1121
# Epoch 52/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1089 - mae: 0.2417 - mse: 0.1089 - val_loss: 0.1137 - val_mae: 0.2456 - val_mse: 0.1137
# Epoch 53/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1090 - mae: 0.2416 - mse: 0.1090 - val_loss: 0.1154 - val_mae: 0.2535 - val_mse: 0.1154
# Epoch 54/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1087 - mae: 0.2413 - mse: 0.1087 - val_loss: 0.1125 - val_mae: 0.2437 - val_mse: 0.1125
# Epoch 55/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1086 - mae: 0.2412 - mse: 0.1086 - val_loss: 0.1106 - val_mae: 0.2409 - val_mse: 0.1106
# Epoch 56/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1084 - mae: 0.2409 - mse: 0.1084 - val_loss: 0.1134 - val_mae: 0.2482 - val_mse: 0.1134
# Epoch 57/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1083 - mae: 0.2408 - mse: 0.1083 - val_loss: 0.1101 - val_mae: 0.2404 - val_mse: 0.1101
# Epoch 58/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1080 - mae: 0.2405 - mse: 0.1080 - val_loss: 0.1149 - val_mae: 0.2487 - val_mse: 0.1149
# Epoch 59/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1079 - mae: 0.2403 - mse: 0.1079 - val_loss: 0.1124 - val_mae: 0.2418 - val_mse: 0.1124
# Epoch 60/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1077 - mae: 0.2402 - mse: 0.1077 - val_loss: 0.1077 - val_mae: 0.2375 - val_mse: 0.1077
# Epoch 61/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1075 - mae: 0.2400 - mse: 0.1075 - val_loss: 0.1173 - val_mae: 0.2486 - val_mse: 0.1173
# Epoch 62/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1072 - mae: 0.2398 - mse: 0.1072 - val_loss: 0.1120 - val_mae: 0.2456 - val_mse: 0.1120
# Epoch 63/100
# 441768/441768 [==============================] - 45s 102us/sample - loss: 0.1072 - mae: 0.2396 - mse: 0.1072 - val_loss: 0.1130 - val_mae: 0.2456 - val_mse: 0.1130
# Epoch 64/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1071 - mae: 0.2394 - mse: 0.1071 - val_loss: 0.1097 - val_mae: 0.2402 - val_mse: 0.1097
# Epoch 65/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1069 - mae: 0.2393 - mse: 0.1069 - val_loss: 0.1120 - val_mae: 0.2455 - val_mse: 0.1120
# Epoch 66/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1068 - mae: 0.2393 - mse: 0.1068 - val_loss: 0.1169 - val_mae: 0.2525 - val_mse: 0.1169
# Epoch 67/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1065 - mae: 0.2391 - mse: 0.1065 - val_loss: 0.1218 - val_mae: 0.2579 - val_mse: 0.1218
# Epoch 68/100
# 441768/441768 [==============================] - 46s 104us/sample - loss: 0.1064 - mae: 0.2389 - mse: 0.1064 - val_loss: 0.1084 - val_mae: 0.2381 - val_mse: 0.1084
# Epoch 69/100
# 441768/441768 [==============================] - 45s 103us/sample - loss: 0.1064 - mae: 0.2389 - mse: 0.1064 - val_loss: 0.1106 - val_mae: 0.2429 - val_mse: 0.1106
# Epoch 70/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1062 - mae: 0.2386 - mse: 0.1062 - val_loss: 0.1091 - val_mae: 0.2409 - val_mse: 0.1091
# Epoch 71/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1062 - mae: 0.2388 - mse: 0.1062 - val_loss: 0.1152 - val_mae: 0.2503 - val_mse: 0.1152
# Epoch 72/100
# 441768/441768 [==============================] - 46s 105us/sample - loss: 0.1062 - mae: 0.2386 - mse: 0.1062 - val_loss: 0.1114 - val_mae: 0.2435 - val_mse: 0.1114
# Epoch 73/100
# 441768/441768 [==============================] - 47s 105us/sample - loss: 0.1058 - mae: 0.2381 - mse: 0.1059 - val_loss: 0.1134 - val_mae: 0.2438 - val_mse: 0.1134
# Epoch 74/100
# 441768/441768 [==============================] - 46s 103us/sample - loss: 0.1056 - mae: 0.2382 - mse: 0.1056 - val_loss: 0.1090 - val_mae: 0.2415 - val_mse: 0.1090
# Epoch 75/100
# 141856/441768 [========>.....................] - ETA: 26s - loss: 0.1053 - mae: 0.2378 - mse: 0.1053Buffered data was truncated after reaching the output size limit.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 95  0.103480  0.235708  0.103480  0.109706  0.239589  0.109706     95
# 96  0.103618  0.235987  0.103618  0.108716  0.243796  0.108716     96
# 97  0.103331  0.235617  0.103331  0.105663  0.239072  0.105663     97
# 98  0.103199  0.235324  0.103199  0.104889  0.237223  0.104889     98
# 99  0.103242  0.235578  0.103242  0.104527  0.234648  0.104527     99

# %%
plt.plot(hist['epoch'], hist['mae'], label='mae')
plt.plot(hist['epoch'], hist['val_mae'], ls='dashed', label='val_mae')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(hist['epoch'], hist['mse'], label='mse')
plt.plot(hist['epoch'], hist['val_mse'], ls='dashed', label='val_mse')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(hist['epoch'], hist['loss'], label='loss')
plt.plot(hist['epoch'], hist['val_loss'], ls='dashed', label='val_loss')
plt.legend(loc='upper left')
plt.show()

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error as mse

mse_score = mse(y_test, preds)
mse_score
# Out:
# 0.10620699578932132

# %%
from sklearn.metrics import mean_absolute_error as mae

mae_score = mae(y_test, preds)
mae_score
# Out:
# 0.23662557784668756

# %%
loss, mae_tf, mse_tf = model.evaluate(X_test, y_test, verbose=2)
print(f"MSE: {mse_tf}\nMAE: {mae_tf}")
# Out:
# 184071/184071 - 10s - loss: 0.1062 - mae: 0.2366 - mse: 0.1062
# MSE: 0.1062069684267044
# MAE: 0.23662523925304413
